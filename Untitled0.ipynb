# %% [markdown]
# <a href="https://colab.research.google.com/github/MaamounMribah/kubeflow-pipeline/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install --upgrade setuptools
# !pip3 install kfp==2.0.0b12 --upgrade --user
# Out:
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (69.0.3)
# Collecting kfp==2.0.0b12
#   Downloading kfp-2.0.0-beta.12.tar.gz (492 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.9/492.9 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click<9,>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from kfp==2.0.0b12) (8.1.7)
# Requirement already satisfied: docstring-parser<1,>=0.7.3 in /root/.local/lib/python3.10/site-packages (from kfp==2.0.0b12) (0.15)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from kfp==2.0.0b12) (2.11.1)
# Requirement already satisfied: google-auth<3,>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from kfp==2.0.0b12) (2.17.3)
# Requirement already satisfied: google-cloud-storage<3,>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from kfp==2.0.0b12) (2.8.0)
# Collecting kfp-pipeline-spec==0.2.0 (from kfp==2.0.0b12)
#   Downloading kfp_pipeline_spec-0.2.0-py3-none-any.whl (12 kB)
# Collecting kfp-server-api==2.0.0a6 (from kfp==2.0.0b12)
#   Downloading kfp-server-api-2.0.0a6.tar.gz (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 kB 7.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting kubernetes<24,>=8.0.0 (from kfp==2.0.0b12)
#   Downloading kubernetes-23.6.0-py2.py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 11.8 MB/s eta 0:00:00
# Collecting protobuf<4,>=3.13.0 (from kfp==2.0.0b12)
#   Downloading protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.0 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML<7,>=5.3 in /usr/local/lib/python3.10/dist-packages (from kfp==2.0.0b12) (6.0.1)
# Requirement already satisfied: requests-toolbelt<1,>=0.8.0 in /root/.local/lib/python3.10/site-packages (from kfp==2.0.0b12) (0.10.1)
# Requirement already satisfied: tabulate<1,>=0.8.6 in /usr/local/lib/python3.10/dist-packages (from kfp==2.0.0b12) (0.9.0)
# Requirement already satisfied: urllib3>=1.15 in /root/.local/lib/python3.10/site-packages (from kfp-server-api==2.0.0a6->kfp==2.0.0b12) (1.26.18)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kfp-server-api==2.0.0a6->kfp==2.0.0b12) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kfp-server-api==2.0.0a6->kfp==2.0.0b12) (2024.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kfp-server-api==2.0.0a6->kfp==2.0.0b12) (2.8.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->kfp==2.0.0b12) (1.62.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->kfp==2.0.0b12) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.1->kfp==2.0.0b12) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.1->kfp==2.0.0b12) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.1->kfp==2.0.0b12) (4.9)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage<3,>=2.2.1->kfp==2.0.0b12) (2.3.3)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage<3,>=2.2.1->kfp==2.0.0b12) (2.7.0)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes<24,>=8.0.0->kfp==2.0.0b12) (69.0.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes<24,>=8.0.0->kfp==2.0.0b12) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes<24,>=8.0.0->kfp==2.0.0b12) (1.3.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage<3,>=2.2.1->kfp==2.0.0b12) (1.5.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.1->kfp==2.0.0b12) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->kfp==2.0.0b12) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->kfp==2.0.0b12) (3.6)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib->kubernetes<24,>=8.0.0->kfp==2.0.0b12) (3.2.2)
# Building wheels for collected packages: kfp, kfp-server-api
#   Building wheel for kfp (setup.py) ... done
#   Created wheel for kfp: filename=kfp-2.0.0b12-py3-none-any.whl size=556208 sha256=eb92f48aca4b80dba449b7afc66b93c25ddf2451dea4bb563c0e9bc2fce69e5a
#   Stored in directory: /root/.cache/pip/wheels/81/59/5e/786a80ee479aa1b24bcf54df9d0af832db73f2dc1bd8f8514f
#   Building wheel for kfp-server-api (setup.py) ... done
#   Created wheel for kfp-server-api: filename=kfp_server_api-2.0.0a6-py3-none-any.whl size=104199 sha256=86d7393eba680c4e7a32c19c0c8de1d02e91013f4fa27cd04db163acef79575f
#   Stored in directory: /root/.cache/pip/wheels/c2/04/5e/57285f0ec1350fb4047eadcdc9da89385cc42680c7d4bade5b
# Successfully built kfp kfp-server-api
# Installing collected packages: protobuf, kfp-server-api, kfp-pipeline-spec, kubernetes, kfp
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.2
#     Uninstalling protobuf-4.25.2:
#       Successfully uninstalled protobuf-4.25.2
#   Attempting uninstall: kfp-server-api
#     Found existing installation: kfp-server-api 2.0.5
#     Uninstalling kfp-server-api-2.0.5:
#       Successfully uninstalled kfp-server-api-2.0.5
#   Attempting uninstall: kfp-pipeline-spec
#     Found existing installation: kfp-pipeline-spec 0.3.0
#     Uninstalling kfp-pipeline-spec-0.3.0:
#       Successfully uninstalled kfp-pipeline-spec-0.3.0
#   Attempting uninstall: kubernetes
#     Found existing installation: kubernetes 26.1.0
#     Uninstalling kubernetes-26.1.0:
#       Successfully uninstalled kubernetes-26.1.0
#   Attempting uninstall: kfp
#     Found existing installation: kfp 2.6.0
#     Uninstalling kfp-2.6.0:
#       Successfully uninstalled kfp-2.6.0
#   WARNING: The scripts dsl-compile, dsl-compile-deprecated and kfp are installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed kfp-2.0.0b12 kfp-pipeline-spec-0.2.0 kfp-server-api-2.0.0a6 kubernetes-23.6.0 protobuf-3.20.3

# %%
# This benchmark measures the performance of run related operations in Kubeflow pipelines, including run durations and latencies of creating/getting/deleting runs.

import random
import kfp

import kfp_server_api
import os
import string
import time
from google.cloud import storage
from kfp.components import *
from datetime import datetime, timezone, timedelta

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats



# CHANGE necessary paramters here
# host is your KFP endpoint
host = 'https://6ee9-41-227-19-17.ngrok-free.app/#/pipelines'
# Use the pipeline you prefer
pipeline_file_url = 'https://github.com/MaamounMribah/kubeflow-pipeline/blob/main/taxi_updated_pool.yaml'
# number of runs you want to create
num_runs = 15
# Periodically check whether the runs have been finished.
run_status_polling_interval_sec = 60


def random_suffix() -> string:
    return ''.join(random.choices(string.ascii_lowercase + string.digits, k=10))

def run_finished(run_status: string) -> bool:
    return run_status in {'Succeeded', 'Failed', 'Error', 'Skipped', 'Terminated'}

def run_succeeded(run_status: string) -> bool:
    return run_status in {'Succeeded'}


if __name__ == '__main__':
    client = kfp.Client(host)

    # Create a pipeline and we'll use its default version to create runs.
    api_url = kfp_server_api.models.ApiUrl(pipeline_file_url)
    api_pipeline = kfp_server_api.models.ApiPipeline(
        name='pipeline-' + random_suffix(),
        url=api_url)
    pipeline = client.pipelines.create_pipeline(body=api_pipeline)
    default_version_id = pipeline.default_version.id

    # Create an experiment.
    experiment_name = 'experiment-' + random_suffix()
    experiment = client.experiments.create_experiment(body={'name' : experiment_name})
    experiment_id = experiment.id

    # Measure create run latency. Note this time is the roundrip latency of CreateRun method. The actual run is
    # not finished when client side gets the CreateRun response. Run duration will be measured below when run is
    # actually finished.
    created_runs = []
    create_run_latencies = []
    for i in range(num_runs):
        resource_references = []
        key = kfp_server_api.models.ApiResourceKey(id=experiment_id, type=kfp_server_api.models.ApiResourceType.EXPERIMENT)
        reference = kfp_server_api.models.ApiResourceReference(key=key, relationship=kfp_server_api.models.ApiRelationship.OWNER)
        resource_references.append(reference)
        key = kfp_server_api.models.ApiResourceKey(id=default_version_id, type=kfp_server_api.models.ApiResourceType.PIPELINE_VERSION)
        reference = kfp_server_api.models.ApiResourceReference(key=key, relationship=kfp_server_api.models.ApiRelationship.CREATOR)
        resource_references.append(reference)
        # If the pipeline you choose needs to specify parameters to create a run, specify it here.
        parameters = []
        parameter = kfp_server_api.ApiParameter(name='pipeline-root', value='gs://jingzhangjz-project-outputs/tfx_taxi_simple/{{workflow.uid}}')
        parameters.append(parameter)
        parameter = kfp_server_api.ApiParameter(name='data-root', value='gs://ml-pipeline-playground/tfx_taxi_simple/data')
        parameters.append(parameter)
        parameter = kfp_server_api.ApiParameter(name='module-file', value='gs://ml-pipeline-playground/tfx_taxi_simple/modules/taxi_utils.py')
        parameters.append(parameter)
        pipeline_spec = kfp_server_api.ApiPipelineSpec(parameters=parameters)

        start = time.perf_counter()
        run_name = 'run-' + random_suffix()
        run = client.runs.create_run(body={'name':run_name, 'resource_references': resource_references, 'pipeline_spec': pipeline_spec})
        dur = time.perf_counter() - start
        create_run_latencies.append(dur)
        created_runs.append(run.run.id)

    # Wait for the runs to finish.
    # TODO(jingzhang36): We can add a timeout for this polling. For now we rely on the timeout of runs in KFP.
    while True:
        all_finished = True
        for i in created_runs:
            run = client.runs.get_run(i)
            if not run_finished(run.run.status):
                all_finished = False
                break
        if all_finished:
            break
        else:
            time.sleep(run_status_polling_interval_sec)

    # When all runs are finished, measure run durations and get run latencies.
    get_run_latencies = []
    succeeded_run_durations = []
    run_results = []
    for i in created_runs:
        start = time.perf_counter()
        run = client.runs.get_run(i)
        dur = time.perf_counter() - start
        get_run_latencies.append(dur)
        if run_succeeded(run.run.status):
            run_results.append('succeeded')
            succeeded_run_durations.append((run.run.finished_at - run.run.created_at).total_seconds())
        else:
            run_results.append('not_succeeded')

    # Measure delete run latency.
    delete_run_latencies = []
    for i in created_runs:
        start = time.perf_counter()
        run = client.runs.delete_run(i)
        dur = time.perf_counter() - start
        delete_run_latencies.append(dur)

    # Cleanup
    client.pipelines.delete_pipeline(pipeline.id)
    client.experiments.delete_experiment(experiment.id)

    # Plots
    fig, axs = plt.subplots(nrows=4, figsize=(10,20))

    axs[0].set(title='Create Run Latency', xlabel='Time (Second)', ylabel='Create')
    sns.distplot(a=create_run_latencies,  ax=axs[0], hist=True, kde=False, rug=True)

    axs[1].set(title='Run Durations', xlabel='Time (Second)', ylabel='Run')
    sns.distplot(a=succeeded_run_durations,  ax=axs[1], hist=True, kde=False, rug=True)

    axs[2].set(title='Get Run Latency', xlabel='Time (Second)', ylabel='Get')
    sns.distplot(a=get_run_latencies,  ax=axs[2], hist=True, kde=False, rug=True)

    axs[3].set(title='Delete Run Latency', xlabel='Time (Second)', ylabel='Delete')
    sns.distplot(a=delete_run_latencies,  ax=axs[3], hist=True, kde=False, rug=True)

    loaded_run_results = pd.DataFrame(np.array(run_results), columns=['result'])
    sns.catplot(x='result', kind="count", data=loaded_run_results)
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# <ipython-input-2-1758647c5219> in <cell line: 43>()
#      49         name='pipeline-' + random_suffix(),
#      50         url=api_url)
# ---> 51     pipeline = client.pipelines.create_pipeline(body=api_pipeline)
#      52     default_version_id = pipeline.default_version.id
#      53
#
# ~/.local/lib/python3.10/site-packages/kfp_server_api/api/pipeline_service_api.py in create_pipeline(self, body, **kwargs)
#      63         """
#      64         kwargs['_return_http_data_only'] = True
# ---> 65         return self.create_pipeline_with_http_info(body, **kwargs)  # noqa: E501
#      66
#      67     def create_pipeline_with_http_info(self, body, **kwargs):  # noqa: E501
#
# ~/.local/lib/python3.10/site-packages/kfp_server_api/api/pipeline_service_api.py in create_pipeline_with_http_info(self, body, **kwargs)
#     147         auth_settings = ['Bearer']  # noqa: E501
#     148
# --> 149         return self.api_client.call_api(
#     150             '/apis/v1beta1/pipelines', 'POST',
#     151             path_params,
#
# ~/.local/lib/python3.10/site-packages/kfp_server_api/api_client.py in call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host)
#     362         """
#     363         if not async_req:
# --> 364             return self.__call_api(resource_path, method,
#     365                                    path_params, query_params, header_params,
#     366                                    body, post_params, files,
#
# ~/.local/lib/python3.10/site-packages/kfp_server_api/api_client.py in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host)
#     186         except ApiException as e:
#     187             e.body = e.body.decode('utf-8') if six.PY3 else e.body
# --> 188             raise e
#     189
#     190         content_type = response_data.getheader('content-type')
#
# ~/.local/lib/python3.10/site-packages/kfp_server_api/api_client.py in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host)
#     179         try:
#     180             # perform request and return response
# --> 181             response_data = self.request(
#     182                 method, url, query_params=query_params, headers=header_params,
#     183                 post_params=post_params, body=body,
#
# ~/.local/lib/python3.10/site-packages/kfp_server_api/api_client.py in request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     405                                             _request_timeout=_request_timeout)
#     406         elif method == "POST":
# --> 407             return self.rest_client.POST(url,
#     408                                          query_params=query_params,
#     409                                          headers=headers,
#
# ~/.local/lib/python3.10/site-packages/kfp_server_api/rest.py in POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     263     def POST(self, url, headers=None, query_params=None, post_params=None,
#     264              body=None, _preload_content=True, _request_timeout=None):
# --> 265         return self.request("POST", url,
#     266                             headers=headers,
#     267                             query_params=query_params,
#
# ~/.local/lib/python3.10/site-packages/kfp_server_api/rest.py in request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     222
#     223         if not 200 <= r.status <= 299:
# --> 224             raise ApiException(http_resp=r)
#     225
#     226         return r
#
# ApiException: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Length': '140', 'Content-Security-Policy': "default-src 'none'", 'Content-Type': 'text/html; charset=utf-8', 'Date': 'Fri, 09 Feb 2024 09:18:41 GMT', 'Ngrok-Trace-Id': '8630472f0efc290ef7c88a35d03faf5d', 'X-Content-Type-Options': 'nosniff', 'X-Powered-By': 'Express'})
# HTTP response body: <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8">
# <title>Error</title>
# </head>
# <body>
# <pre>Cannot POST /</pre>
# </body>
# </html>
